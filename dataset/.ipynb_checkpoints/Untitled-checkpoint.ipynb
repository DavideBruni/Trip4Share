# %%
import json
with open('dataset_trips_extended_mongo.json', 'r', encoding="utf8") as f:
    data = json.load(f)
data[0].keys()
# Out:
# dict_keys(['_id', 'title', 'description', 'tags', 'itinerary', 'departureDate', 'returnDate', 'price', 'info', 'destination', 'likes', 'whatsIncluded', 'whatsNotIncluded'])

# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-5.3.0.tar.gz (157 kB)
#      -------------------------------------- 157.8/157.8 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pytz in c:\users\david\anaconda3\envs\dmml\lib\site-packages (from neo4j) (2022.1)
# Building wheels for collected packages: neo4j
#   Building wheel for neo4j (pyproject.toml): started
#   Building wheel for neo4j (pyproject.toml): finished with status 'done'
#   Created wheel for neo4j: filename=neo4j-5.3.0-py3-none-any.whl size=221872 sha256=271184e7bfcb1d0487b1dc4675163d17c41bbc0514af031fdfdcca3206bfa48c
#   Stored in directory: c:\users\david\appdata\local\pip\cache\wheels\65\6f\9d\e5a51f176926b84dc3b68d98ab936756c9974c0ebcf3de9c0b
# Successfully built neo4j
# Installing collected packages: neo4j
# Successfully installed neo4j-5.3.0

# %%
from random import seed
from random import random
from neo4j import GraphDatabase
import datetime

class Neo4jDAO:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def create_trip(self, trip):
        with self.driver.session() as session:
            res = session.execute_write(self._create_trips, trip)
            print(res)
            
    def create_user(self, username):
        with self.driver.session() as session:
            res = session.execute_write(self._create_user, username)
            print(res)

    def create_ORGANIZED_BY(self,trip_id,username):
        with self.driver.session() as session:
            res = session.execute_write(self._create_org_rel, trip_id, username)
            print(res)
            
    def create_JOIN(self,trip_id,username):
        with self.driver.session() as session:
            res = session.execute_write(self._create_join_rel, trip_id, username)
            print(res)        
            
    def create_follow(self,to_follow, follower):
        with self.driver.session() as session:
            res = session.execute_write(self._create_follow_rel, to_follow, follower)
            print(res) 
            
    @staticmethod
    def _create_follow_rel(tx, to_follow, follower):
        result = tx.run("MATCH (r1:RegisteredUser {username: $user1}),(r2:RegisteredUser {username: $user2}) "
                        "CREATE (r1)-[f:FOLLOW]->(r2) "
                        "RETURN type(f)",user1=follower, user2=to_follow)
        return result.single()[0]
    @staticmethod
    def _create_org_rel(tx,trip_id, username):
        result = tx.run("MATCH (r:RegisteredUser),(t:Trip) "
                        "WHERE r.username = $username AND t._id = $_id "
                        "CREATE (t)-[o:JOIN]->(r) "
                        "RETURN type(o)",username=username, _id=trip_id)
        return result.single()[0]

    
    @staticmethod
    def _create_join_rel(tx,trip_id, username):
        rand_n = random();
        if rand_n>0.05 and rand_n<0.10:
            status = "pending"
        elif rand_n < 0.05:
            status = "rejected"
        else:
            status = "accepted"
            deleted = True
        result = tx.run("MATCH (r:RegisteredUser),(t:Trip) "
                        "WHERE r.username = $username AND t._id = $_id "
                        "CREATE (r)-[j:JOIN {status: $status}]->(t) "
                        "RETURN type(j)",username=username, _id=trip_id, status = status)
        return result.single()[0]
        
    @staticmethod
    def _create_trips(tx,trip):
        seed(1)
        if random()>0.1:
            deleted = False
        else:
            deleted = True
        depDate = datetime.datetime.fromtimestamp(int(trip['departureDate']['$date']['$numberLong'])/1000).strftime('%Y-%m-%d')
        retDate = datetime.datetime.fromtimestamp(int(trip['returnDate']['$date']['$numberLong'])/1000).strftime('%Y-%m-%d')
        
        result = tx.run("CREATE (t:Trip) "
                        "SET t._id=$_id, t.destination = $destination, t.title = $title, "
                        "t.departureDate = date($departureDate), "
                        "t.returnDate = date($returnDate), t.imgUrl = $imgUrl, t.deleted=$deleted "
                        "RETURN t.destination ",_id=trip['_id']['$oid'], destination=trip['destination'],
                       title=trip['title'], departureDate= depDate,
                       returnDate =retDate, imgUrl="",deleted=deleted)
        return result.single()[0]


    @staticmethod
    def _create_user(tx,username):
        result = tx.run("CREATE (r:RegisteredUser) "
                        "SET r.username =$username "
                         "RETURN r.username ",username = username)
        return result.single()[0]
    
    @staticmethod
    def create_follow
# Out:
#   Input In [31]
#     def create_follow
#                      ^
# SyntaxError: invalid syntax

# %%
if __name__ == "__main__":
    connection = Neo4jDAO("bolt://localhost:7687", "neo4j", "root")
    for trip in data:
        connection.create_trip(trip)
    connection.close()
# Out:
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# ecuador
# norveggia
# vietnam
# vietnam
# vietnam
# vietnam
# vietnam
# indonesia
# islanda
# indonesia
# indonesia
# indonesia
# indonesia
# brasile
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# mozambico
# india
# lapponia
# tanzania
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# islanda
# islanda
# islanda
# uzbekistan
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# giappone
# giappone
# namibia
# namibia
# patagonia
# filippine
# nuova zelanda
# hawaii
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# capodanno
# capodanno
# srilanka
# kenya
# spagna
# norveggia
# norveggia
# norveggia
# zanzibar
# lapponia
# islanda
# islanda
# filippine
# petra
# giappone
# stati uniti
# islanda
# giappone
# madeira
# madeira
# madeira
# tanzania
# lapponia
# islanda
# islanda
# colombia
# giappone
# uganda
# peru
# peru
# peru
# cina
# guatemala
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# stati uniti
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# stati uniti
# stati uniti
# grecia
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# yucatan
# thailandia
# cappadocia
# lapponia
# lapponia
# lapponia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# oman
# giordania
# stati uniti
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# nepal
# islanda
# messico
# messico
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# ecuador
# norveggia
# vietnam
# vietnam
# vietnam
# vietnam
# vietnam
# indonesia
# islanda
# indonesia
# indonesia
# indonesia
# indonesia
# brasile
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# mozambico
# india
# lapponia
# tanzania
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# islanda
# islanda
# islanda
# uzbekistan
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# giappone
# giappone
# namibia
# namibia
# patagonia
# filippine
# nuova zelanda
# hawaii
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# capodanno
# capodanno
# srilanka
# kenya
# spagna
# norveggia
# norveggia
# norveggia
# zanzibar
# lapponia
# islanda
# islanda
# filippine
# petra
# giappone
# stati uniti
# islanda
# giappone
# madeira
# madeira
# madeira
# tanzania
# lapponia
# islanda
# islanda
# colombia
# giappone
# uganda
# peru
# peru
# peru
# cina
# guatemala
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# stati uniti
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# stati uniti
# stati uniti
# grecia
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# yucatan
# thailandia
# cappadocia
# lapponia
# lapponia
# lapponia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# oman
# giordania
# stati uniti
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# nepal
# islanda
# messico
# messico
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# ecuador
# norveggia
# vietnam
# vietnam
# vietnam
# vietnam
# vietnam
# indonesia
# islanda
# indonesia
# indonesia
# indonesia
# indonesia
# brasile
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# mozambico
# india
# lapponia
# tanzania
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# islanda
# islanda
# islanda
# uzbekistan
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# giappone
# giappone
# namibia
# namibia
# patagonia
# filippine
# nuova zelanda
# hawaii
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# capodanno
# capodanno
# srilanka
# kenya
# spagna
# norveggia
# norveggia
# norveggia
# zanzibar
# lapponia
# islanda
# islanda
# filippine
# petra
# giappone
# stati uniti
# islanda
# giappone
# madeira
# madeira
# madeira
# tanzania
# lapponia
# islanda
# islanda
# colombia
# giappone
# uganda
# peru
# peru
# peru
# cina
# guatemala
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# peru
# stati uniti
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# lapponia
# stati uniti
# stati uniti
# grecia
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# hawaii
# yucatan
# thailandia
# cappadocia
# lapponia
# lapponia
# lapponia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# oman
# giordania
# stati uniti
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# giappone
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# ecuador
# norveggia
# vietnam
# vietnam
# vietnam
# vietnam
# vietnam
# indonesia
# islanda
# indonesia
# indonesia
# indonesia
# indonesia
# brasile
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# mozambico
# india
# lapponia
# tanzania
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# islanda
# islanda
# islanda
# uzbekistan
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# giappone
# giappone
# namibia
# namibia
# patagonia
# filippine
# nuova zelanda
# hawaii
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# capodanno
# capodanno
# srilanka
# kenya
# spagna
# norveggia
# norveggia
# norveggia
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# messico
# norveggia
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# stati uniti
# ecuador
# norveggia
# vietnam
# vietnam
# vietnam
# vietnam
# vietnam
# indonesia
# islanda
# indonesia
# indonesia
# indonesia
# indonesia
# brasile
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# giordania
# mozambico
# india
# lapponia
# tanzania
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# marocco
# islanda
# islanda
# islanda
# uzbekistan
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# islanda
# giappone
# giappone
# namibia
# namibia
# patagonia
# filippine
# nuova zelanda
# hawaii
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
# cappadocia
organizer = users[1:228]
# 6 viaggio per utente
# Out:
# 1135

# %%
connection = Neo4jDAO("bolt://localhost:7687", "neo4j", "root")
start = 0
end = 6
try:
    for user in organizer:
        for i in range(start,end):
            print(data[i]['_id']['$oid'])
            print(user['username'])
            connection.create_ORGANIZED_BY(data[i]['_id']['$oid'],user['username'])
        start = end + 1
        end = end + 6
except:
    print(end)
finally: 
    connection.close()
# Out:
# 6

# %%
import numpy as np
mu, sigma = 8, 7 # mean and standard deviation
s = np.random.normal(mu, sigma, len(data))
s
connection = Neo4jDAO("bolt://localhost:7687", "neo4j", "root")
start = 0
end = 6
joiner = users[1:]
j=0;
for trip in data:
    print(trip['_id']['$oid'])
    for i in range(0,int(s[j])):
        try:
            u = joiner[int(i+(random()*1120))]['username']
        except:
            u = joiner[i]['username']
        print(u)
        connection.create_JOIN(trip['_id']['$oid'],u)
    j=j+1
# Out:
# 63a318aa952f5ede28c42818
# Nicola17
# JOIN
# Bianchi_11
# JOIN
# Gianluca0
# JOIN
# A_22
# JOIN
# Francioso_8
# JOIN
# Silvia_5
# JOIN
# Gemelli_10
# JOIN
# Viv_4
# JOIN
# Erminia_2
# JOIN
# 63a318aa952f5ede28c42819
# Eugenio17
# JOIN
# Fabrizio_6
# JOIN
# GILARDI_10
# JOIN
# Elvira_11
# JOIN
# Longobardi_21
# JOIN
# Alex13
# JOIN
# Loredana_4
# JOIN
# Lucia_6
# JOIN
# stefania_5
# JOIN
# 63a318aa952f5ede28c4281a
# Bullitta_10
# JOIN
# Murray_10
# JOIN
# Matteo_16
# JOIN
# Stefano22
# JOIN
# Mirko_10
# JOIN
# Antonio_15
# JOIN
# 63a318aa952f5ede28c4281b
# Alex13
# JOIN
# Giulia_3
# JOIN
# Erica_8
# JOIN
# Elena_2
# JOIN
# Alessandra_1
# JOIN
# Mirco18
# JOIN
# Pivetta_22
# JOIN
# Stefano_5
# JOIN
# Elena_4
# JOIN
# Bruno_9
# JOIN
# Maria9
# JOIN
# Alessia21
# JOIN
# Sparnaccini_10
# JOIN
# Vicchio_10
# JOIN
# Monica_15
# JOIN
# Marzia12
# JOIN
# cliente13
# JOIN
# Serena_0
# JOIN
# Arianna3
# JOIN
# 63a318aa952f5ede28c4281c
# 63a318aa952f5ede28c4281d
# D'Antuono_22
# JOIN
# Bianchi_9
# JOIN
# Neri_20
# JOIN
# 63a318aa952f5ede28c4281e
# Andrea4
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Alessio16
# JOIN
# Carlo21
# JOIN
# Utente6
# JOIN
# Federico6
# JOIN
# Pardini_21
# JOIN
# Francesca_19
# JOIN
# Nicolò_22
# JOIN
# Angela_13
# JOIN
# 63a318aa952f5ede28c4281f
# Alessia_18
# JOIN
# Arianna3
# JOIN
# Alberto_20
# JOIN
# Bodini_10
# JOIN
# MM20
# JOIN
# Simone_15
# JOIN
# Benedetta7
# JOIN
# Rossi_8
# JOIN
# Walter_1
# JOIN
# Leonardo_18
# JOIN
# Stefano_5
# JOIN
# Diego_8
# JOIN
# Potito21
# JOIN
# Bianchi_7
# JOIN
# 63a318aa952f5ede28c42820
# Mario7
# JOIN
# Mariagrazia22
# JOIN
# Marco15
# JOIN
# Marco_9
# JOIN
# Andrea_3
# JOIN
# GIADA12
# JOIN
# Amalia_6
# JOIN
# Sulis_5
# JOIN
# Lu_13
# JOIN
# Tiffany_2
# JOIN
# 63a318aa952f5ede28c42821
# Rossi_4
# JOIN
# Laboratorio4
# JOIN
# Nuzzo_14
# JOIN
# Pardini_6
# JOIN
# Magri_10
# JOIN
# Lorenzo11
# JOIN
# Belletti_10
# JOIN
# Fabio_13
# JOIN
# Alessandro_9
# JOIN
# S.N.C. di Selvaggio Noem_8
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# 63a318aa952f5ede28c42822
# Silvia_22
# JOIN
# AIELLO_17
# JOIN
# Fabio_15
# JOIN
# Giovanni_14
# JOIN
# cliente_5
# JOIN
# Zuppetti_13
# JOIN
# Andrea_11
# JOIN
# Loni_2
# JOIN
# Bea5
# JOIN
# Di Domenico_16
# JOIN
# Jessica_17
# JOIN
# Jasmine19
# JOIN
# Daniele15
# JOIN
# Federica_17
# JOIN
# Ursenna17
# JOIN
# 63a318aa952f5ede28c42823
# Alessandro4
# JOIN
# Pompili_11
# JOIN
# Pacchiana_4
# JOIN
# Mariavittoria10
# JOIN
# Barletta_18
# JOIN
# Giulia_20
# JOIN
# 63a318aa952f5ede28c42824
# VS_18
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Matilde9
# JOIN
# Nicola_5
# JOIN
# Solinas_22
# JOIN
# Sara18
# JOIN
# Rochester_5
# JOIN
# Nicole1
# JOIN
# Stefano14
# JOIN
# Anna3
# JOIN
# 63a318aa952f5ede28c42825
# Lucia_6
# JOIN
# Andrea_0
# JOIN
# Podavini_8
# JOIN
# Roberto_1
# JOIN
# Michela4
# JOIN
# Corona15
# JOIN
# Cucci_5
# JOIN
# Giulia5
# JOIN
# Utente6
# JOIN
# Martina15
# JOIN
# Claudia_21
# JOIN
# Donato18
# JOIN
# Stefania7
# JOIN
# andrea10
# JOIN
# Matteo22
# JOIN
# 63a318aa952f5ede28c42826
# Martina_2
# JOIN
# Poli_7
# JOIN
# Martina_2
# JOIN
# Solinas_5
# JOIN
# Alessandro_13
# JOIN
# Federico17
# JOIN
# Tamai_1
# JOIN
# Flaminia_0
# JOIN
# Lanna_0
# JOIN
# Elena_0
# JOIN
# Francesca18
# JOIN
# Stefano_5
# JOIN
# Martina16
# JOIN
# Carmine9
# JOIN
# 63a318aa952f5ede28c42827
# Donato18
# JOIN
# Dorotea18
# JOIN
# Chiara_0
# JOIN
# Chiara18
# JOIN
# Viv_4
# JOIN
# Fabio_13
# JOIN
# Allegrini_20
# JOIN
# Solinas_7
# JOIN
# Neri_12
# JOIN
# Silvia_22
# JOIN
# 63a318aa952f5ede28c42828
# Desiree15
# JOIN
# Marco15
# JOIN
# Lidia Sciacca_15
# JOIN
# Paola_10
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Modena_22
# JOIN
# Michela0
# JOIN
# Rossi_11
# JOIN
# 63a318aa952f5ede28c42829
# Elio5
# JOIN
# SIMONA19
# JOIN
# Ghiringhelli_10
# JOIN
# Filippo_16
# JOIN
# Sara1
# JOIN
# Poma_3
# JOIN
# Claudia_21
# JOIN
# Andrea4
# JOIN
# Carmine9
# JOIN
# Martina8
# JOIN
# Martinelli_17
# JOIN
# Sbrana_15
# JOIN
# Nicole_10
# JOIN
# D'Agostino_1
# JOIN
# Anna_20
# JOIN
# Francesco6
# JOIN
# Caterina_16
# JOIN
# 63a318aa952f5ede28c4282a
# Vittoria Salcerini_10
# JOIN
# Re._2
# JOIN
# Bianchi_11
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Chiara_21
# JOIN
# Cristiano_5
# JOIN
# Mariarita_1
# JOIN
# Crespi_1
# JOIN
# Lotti_20
# JOIN
# Gloria11
# JOIN
# Nicola_16
# JOIN
# D'Agostini_20
# JOIN
# 63a318aa952f5ede28c4282b
# Ariu_21
# JOIN
# 63a318aa952f5ede28c4282c
# FEDERICA_15
# JOIN
# Annalisa13
# JOIN
# Giulia17
# JOIN
# VITTORIO7
# JOIN
# Beatrice_7
# JOIN
# VITTORIO7
# JOIN
# Raluca15
# JOIN
# Clara_1
# JOIN
# Stefano18
# JOIN
# Salvatore_4
# JOIN
# cliente_11
# JOIN
# Virginia_0
# JOIN
# Ruggiero_2
# JOIN
# Daniele16
# JOIN
# Alice_0
# JOIN
# Raffaella_18
# JOIN
# Pietro9
# JOIN
# Michele_0
# JOIN
# Andrea17
# JOIN
# 63a318aa952f5ede28c4282d
# 63a318aa952f5ede28c4282e
# Serena21
# JOIN
# Manuela0
# JOIN
# Valerio10
# JOIN
# Colizzi_1
# JOIN
# Corona15
# JOIN
# Aprea_11
# JOIN
# 63a318aa952f5ede28c4282f
# Ranaldo_10
# JOIN
# marco6
# JOIN
# Mattia16
# JOIN
# Riccardo14
# JOIN
# 63a318aa952f5ede28c42830
# Elena_2
# JOIN
# Casoni_9
# JOIN
# Giuliano_12
# JOIN
# deborah1
# JOIN
# Mr4
# JOIN
# Roberta Mussini_1
# JOIN
# Laura7
# JOIN
# 63a318aa952f5ede28c42831
# Alessandro_13
# JOIN
# Loni_0
# JOIN
# Mariangela9
# JOIN
# Irene_2
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Fabiola_5
# JOIN
# 63a318aa952f5ede28c42832
# Elisa12
# JOIN
# Francesca18
# JOIN
# Claire_12
# JOIN
# Alessia0
# JOIN
# Alessandro17
# JOIN
# pizzichini_1
# JOIN
# Valeria_12
# JOIN
# Federica_3
# JOIN
# Andrea14
# JOIN
# Simone_13
# JOIN
# 63a318aa952f5ede28c42833
# Vicchio_10
# JOIN
# Alessandro15
# JOIN
# Giovanni Casella_22
# JOIN
# Alberto2
# JOIN
# Giulia_11
# JOIN
# Fusilli_4
# JOIN
# Debora_22
# JOIN
# Sabrina3
# JOIN
# Vannicola_10
# JOIN
# Giulia5
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# 63a318aa952f5ede28c42834
# Martina3
# JOIN
# Maria9
# JOIN
# Giulia9
# JOIN
# 63a318aa952f5ede28c42835
# Tamai_1
# JOIN
# Pulito_1
# JOIN
# Giovanna22
# JOIN
# Elena_17
# JOIN
# 63a318aa952f5ede28c42836
# Pagnotta_14
# JOIN
# Martina16
# JOIN
# Iacopo9
# JOIN
# Ilaria8
# JOIN
# Loni_18
# JOIN
# Loni_8
# JOIN
# Scotton_14
# JOIN
# Rossi_11
# JOIN
# Cristina_14
# JOIN
# Allasia_8
# JOIN
# 63a318aa952f5ede28c42837
# Neri_14
# JOIN
# Solinas_1
# JOIN
# Martina16
# JOIN
# Roberto14
# JOIN
# Diana12
# JOIN
# Stefania_11
# JOIN
# Moreschi_18
# JOIN
# Ale_7
# JOIN
# Bianchi_7
# JOIN
# Benedetta7
# JOIN
# Marcellino_18
# JOIN
# Morelli_6
# JOIN
# Neri_20
# JOIN
# 63a318aa952f5ede28c42838
# 63a318aa952f5ede28c42839
# Samantha_22
# JOIN
# Alessandro1
# JOIN
# Elena_20
# JOIN
# Loni_19
# JOIN
# Angela Bettini_20
# JOIN
# Alessandra_13
# JOIN
# Martina11
# JOIN
# Rossi_4
# JOIN
# Virginia17
# JOIN
# Mattia_4
# JOIN
# Enzo_10
# JOIN
# Triveri_15
# JOIN
# Walter_1
# JOIN
# Luca_13
# JOIN
# Elena_1
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Sulis_20
# JOIN
# Colizzi_1
# JOIN
# Caterina_8
# JOIN
# Martinelli_17
# JOIN
# Corini_22
# JOIN
# Giovanni_14
# JOIN
# silvia10
# JOIN
# Anna22
# JOIN
# Amadei_1
# JOIN
# 63a318aa952f5ede28c4283a
# Volpini_13
# JOIN
# Anna_0
# JOIN
# Angela_20
# JOIN
# Michael_1
# JOIN
# 63a318aa952f5ede28c4283b
# Giovanni Casella_22
# JOIN
# Maria_15
# JOIN
# Grasso_0
# JOIN
# Michela0
# JOIN
# Alaimo_14
# JOIN
# Andrea_3
# JOIN
# Davide_20
# JOIN
# 63a318aa952f5ede28c4283c
# Arianna_1
# JOIN
# Solinas_10
# JOIN
# Marianna16
# JOIN
# Denise6
# JOIN
# Sulis_10
# JOIN
# Sara_20
# JOIN
# Niccolò_1
# JOIN
# Michela0
# JOIN
# Marco_16
# JOIN
# Scotton_14
# JOIN
# Francesco_11
# JOIN
# Solinas_11
# JOIN
# Malvone_11
# JOIN
# Bianchi_1
# JOIN
# Ilaria_0
# JOIN
# Elia_8
# JOIN
# Lisa_7
# JOIN
# Giuseppe_16
# JOIN
# Davide16
# JOIN
# Camilla7
# JOIN
# Croce_20
# JOIN
# Nocentini_10
# JOIN
# Ursenna17
# JOIN
# Silvia11
# JOIN
# 63a318aa952f5ede28c4283d
# Ale_7
# JOIN
# Formentini_11
# JOIN
# Federica_5
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Simone_1
# JOIN
# Ilaria_0
# JOIN
# Andrea1
# JOIN
# Arianna3
# JOIN
# Andrea_11
# JOIN
# klant1
# JOIN
# Francesco13
# JOIN
# Francesco_21
# JOIN
# Paola_10
# JOIN
# Dario_2
# JOIN
# Paolo1
# JOIN
# 63a318aa952f5ede28c4283e
# 63a318aa952f5ede28c4283f
# Sara_20
# JOIN
# Gianluca_19
# JOIN
# Andrea18
# JOIN
# Amadei_1
# JOIN
# Elisabetta_9
# JOIN
# Giorgio_5
# JOIN
# K.H4
# JOIN
# Fe1
# JOIN
# Andreea_8
# JOIN
# 63a318aa952f5ede28c42840
# Andrea17
# JOIN
# Lidia0
# JOIN
# Annalisa_15
# JOIN
# Ursenna17
# JOIN
# Luigi15
# JOIN
# Elena19
# JOIN
# Martina4
# JOIN
# users_it_8
# JOIN
# Marozzi_6
# JOIN
# Bez_20
# JOIN
# Andrea13
# JOIN
# Rettore_11
# JOIN
# Pardini_0
# JOIN
# Merlo_2
# JOIN
# 63a318aa952f5ede28c42841
# Chiara_22
# JOIN
# Solinas_6
# JOIN
# Alexis_1
# JOIN
# Cris4
# JOIN
# Rossi_5
# JOIN
# E!_22
# JOIN
# Ileana21
# JOIN
# Stefano_14
# JOIN
# Chaohao17
# JOIN
# Vittoria_17
# JOIN
# Andrea2
# JOIN
# Arianna3
# JOIN
# Elena_2
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Emanuela_20
# JOIN
# Mario7
# JOIN
# Carlotta11
# JOIN
# Manuela6
# JOIN
# Caterina_8
# JOIN
# Luca_13
# JOIN
# Matteo_13
# JOIN
# Mauro_2
# JOIN
# Claudio1
# JOIN
# Poli_7
# JOIN
# 63a318aa952f5ede28c42842
# Andrea_3
# JOIN
# Vittoria_17
# JOIN
# Beatrice_18
# JOIN
# claudetter_15
# JOIN
# Giulia5
# JOIN
# B_10
# JOIN
# Alessia4
# JOIN
# Lucia21
# JOIN
# Sulis_6
# JOIN
# GIUSTOLISI_8
# JOIN
# 63a318aa952f5ede28c42843
# 63a318aa952f5ede28c42844
# Antonio9
# JOIN
# Desiree15
# JOIN
# Merler_1
# JOIN
# Michela_19
# JOIN
# Maja_13
# JOIN
# 63a318aa952f5ede28c42845
# Claudia_21
# JOIN
# Marco15
# JOIN
# Bonesi_2
# JOIN
# Nicole15
# JOIN
# Marco_10
# JOIN
# Andrea4
# JOIN
# Giacomo_5
# JOIN
# 63a318aa952f5ede28c42846
# Elena_2
# JOIN
# Melania_16
# JOIN
# Mariagrazia22
# JOIN
# Nicole15
# JOIN
# Nicoletta_11
# JOIN
# Stefania7
# JOIN
# 63a318aa952f5ede28c42847
# Chiara_0
# JOIN
# Nicoló_4
# JOIN
# 63a318aa952f5ede28c42848
# 63a318aa952f5ede28c42849
# Gianluca_17
# JOIN
# Solinas_8
# JOIN
# GILARDI_10
# JOIN
# Andrea_4
# JOIN
# GIUSEPPE_20
# JOIN
# Neri_20
# JOIN
# Malvone_11
# JOIN
# Solinas_3
# JOIN
# Barbara10
# JOIN
# Neri_7
# JOIN
# Pedrazzini_7
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Cantoni_4
# JOIN
# 63a318aa952f5ede28c4284a
# Sabrina_13
# JOIN
# Roberta_7
# JOIN
# Chiara6
# JOIN
# Carpinelli_10
# JOIN
# S.M.9
# JOIN
# Fabio_10
# JOIN
# Francesco_1
# JOIN
# Francesco13
# JOIN
# 63a318aa952f5ede28c4284b
# Sulis_22
# JOIN
# Beatrice_7
# JOIN
# Melania_16
# JOIN
# Walter_1
# JOIN
# Luca1
# JOIN
# Veronica_14
# JOIN
# cliente_2
# JOIN
# Andrea_16
# JOIN
# 63a318aa952f5ede28c4284c
# 63a318aa952f5ede28c4284d
# Martina4
# JOIN
# Simone_6
# JOIN
# Solinas_9
# JOIN
# Luca_13
# JOIN
# Giulia18
# JOIN
# Sara18
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Luca1
# JOIN
# Bullitta_10
# JOIN
# Desiree15
# JOIN
# Giuseppe_11
# JOIN
# Caterina_8
# JOIN
# Chiara_1
# JOIN
# Francesca_22
# JOIN
# Ursenna17
# JOIN
# Alessio15
# JOIN
# 63a318aa952f5ede28c4284e
# Neri_16
# JOIN
# Martina_15
# JOIN
# Brenda_2
# JOIN
# Bianca3
# JOIN
# Mantua_7
# JOIN
# 63a318aa952f5ede28c4284f
# 63a318aa952f5ede28c42850
# Gloria_2
# JOIN
# Deborah_2
# JOIN
# Gloria_13
# JOIN
# ilenia0
# JOIN
# Chaohao17
# JOIN
# Antonio13
# JOIN
# Nicola_5
# JOIN
# Marik_2
# JOIN
# Carmela_17
# JOIN
# Amalia_6
# JOIN
# Gaia_15
# JOIN
# Bianchi_19
# JOIN
# Nardone_5
# JOIN
# Solinas_18
# JOIN
# Antonio14
# JOIN
# Andrea4
# JOIN
# Umberto_2
# JOIN
# Bianchi_7
# JOIN
# Minella_22
# JOIN
# Nuzzo_14
# JOIN
# 63a318aa952f5ede28c42851
# 63a318aa952f5ede28c42852
# De Nardi_12
# JOIN
# Lisa_7
# JOIN
# Elena_2
# JOIN
# Agnese_5
# JOIN
# D'Antuono_22
# JOIN
# 63a318aa952f5ede28c42853
# 63a318aa952f5ede28c42854
# 63a318aa952f5ede28c42855
# 63a318aa952f5ede28c42856
# Mattia_5
# JOIN
# Fabrizio_6
# JOIN
# marco6
# JOIN
# Marcellino_18
# JOIN
# Chiara_21
# JOIN
# cliente_11
# JOIN
# Martina16
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Alex9
# JOIN
# Gentili_15
# JOIN
# Alessandra_16
# JOIN
# 63a318aa952f5ede28c42857
# C._11
# JOIN
# Andrea_1
# JOIN
# Sulis_20
# JOIN
# Giovanni_14
# JOIN
# Salvo_15
# JOIN
# 63a318aa952f5ede28c42858
# Enrico6
# JOIN
# Giulia3
# JOIN
# roberto_13
# JOIN
# Kevin21
# JOIN
# Mc10
# JOIN
# giuseppe pandini_1
# JOIN
# 63a318aa952f5ede28c42859
# Paola16
# JOIN
# Merler_1
# JOIN
# Michelangelo_20
# JOIN
# Mattia_5
# JOIN
# Michele_0
# JOIN
# Chiara_0
# JOIN
# Sophie_16
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Notarantonio_7
# JOIN
# Leonardo11
# JOIN
# Roberta_7
# JOIN
# klant1
# JOIN
# Juri2
# JOIN
# Sara_20
# JOIN
# stefania_5
# JOIN
# Andrea_0
# JOIN
# Matteo14
# JOIN
# 63a318aa952f5ede28c4285a
# Tommaso18
# JOIN
# Bocchino_18
# JOIN
# Lidia Sciacca_15
# JOIN
# Sirizzotti_16
# JOIN
# Valentina22
# JOIN
# Simone14
# JOIN
# Elena_0
# JOIN
# Alex_15
# JOIN
# 63a318aa952f5ede28c4285b
# Giulia_14
# JOIN
# Marco_9
# JOIN
# Paola16
# JOIN
# Loni_17
# JOIN
# Tieghi_1
# JOIN
# Nicola_5
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Pivetta_22
# JOIN
# Federico16
# JOIN
# Luisa_10
# JOIN
# Federica_17
# JOIN
# Venturin_5
# JOIN
# 63a318aa952f5ede28c4285c
# 63a318aa952f5ede28c4285d
# Gaia_15
# JOIN
# Maja_13
# JOIN
# 63a318aa952f5ede28c4285e
# Neri_15
# JOIN
# Loni_12
# JOIN
# Diego_8
# JOIN
# BRESCHI_4
# JOIN
# Valentina7
# JOIN
# Andrea1
# JOIN
# Mattia_5
# JOIN
# Laura22
# JOIN
# 63a318aa952f5ede28c4285f
# Carmen_1
# JOIN
# Solinas_10
# JOIN
# Iacopo_6
# JOIN
# Carmine_16
# JOIN
# Antonio De Bellis_10
# JOIN
# Corona15
# JOIN
# Alex_15
# JOIN
# Fabrizio_0
# JOIN
# Deborah_16
# JOIN
# Ursenna17
# JOIN
# Crespi_1
# JOIN
# Ferretto_6
# JOIN
# Rachele_8
# JOIN
# Giuseppe0
# JOIN
# Elena_20
# JOIN
# Giuseppe_1
# JOIN
# Pardini_6
# JOIN
# GILARDI_10
# JOIN
# Neri_5
# JOIN
# Perillo_14
# JOIN
# 63a318aa952f5ede28c42860
# Clara_1
# JOIN
# Leonardo11
# JOIN
# VITTORIO7
# JOIN
# Alessio16
# JOIN
# Angela_20
# JOIN
# Fiorella9
# JOIN
# Sartori_10
# JOIN
# 63a318aa952f5ede28c42861
# Marco_9
# JOIN
# Loni_14
# JOIN
# Michela4
# JOIN
# Andrea_16
# JOIN
# Anna_0
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# C:\Users\david\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\result.py:461: UserWarning: Expected a result with a single record, but found multiple.
#   warn("Expected a result with a single record, "
# JOIN
# Roberta6
# JOIN
# Martina_2
# JOIN
# Bianca3
# JOIN
# cliente_11
# JOIN
# Giannuzzi_10
# JOIN
# Loredana_4
# JOIN
# Veronica_13
# JOIN
# Ciani_10
# JOIN
# De Mutiis_20
# JOIN
# Riccardo_22
# JOIN
# Salvatore_4
# JOIN
# Annalisa_15
# JOIN
# Martina_5
# JOIN
# Andrea18
# JOIN
# Mantua_7
# JOIN
# Mattia7
# JOIN
# Nicosia_11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 10>()
#      16         u = joiner[i]['username']
#      17     print(u)
# ---> 18     connection.create_JOIN(trip['_id']['$oid'],u)
#      19 j=j+1
#
# Input In [13], in Neo4jDAO.create_JOIN(self, trip_id, username)
#      29 def create_JOIN(self,trip_id,username):
#      30     with self.driver.session() as session:
# ---> 31         res = session.execute_write(self._create_join_rel, trip_id, username)
#      32         print(res)
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\session.py:672, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     627 def execute_write(
#     628     self,
#     629     transaction_function: t.Callable[
#    (...)
#     632     *args: _P.args,  **kwargs: _P.kwargs
#     633 ) -> _R:
#     634     """Execute a unit of work in a managed write transaction.
#     635
#     636     .. note::
#    (...)
#     670     .. versionadded:: 5.0
#     671     """
# --> 672     return self._run_transaction(
#     673         WRITE_ACCESS, transaction_function, *args, **kwargs
#     674     )
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\session.py:480, in Session._run_transaction(self, access_mode, transaction_function, *args, **kwargs)
#     478 while True:
#     479     try:
# --> 480         self._open_transaction(
#     481             tx_cls=ManagedTransaction,
#     482             access_mode=access_mode, metadata=metadata,
#     483             timeout=timeout
#     484         )
#     485         tx = self._transaction
#     486         try:
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\session.py:396, in Session._open_transaction(self, tx_cls, access_mode, metadata, timeout)
#     389 self._transaction = tx_cls(
#     390     self._connection, self._config.fetch_size,
#     391     self._transaction_closed_handler,
#     392     self._transaction_error_handler,
#     393     self._transaction_cancel_handler
#     394 )
#     395 bookmarks = self._get_bookmarks()
# --> 396 self._transaction._begin(
#     397     self._config.database, self._config.impersonated_user,
#     398     bookmarks, access_mode, metadata, timeout
#     399 )
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\work\transaction.py:83, in TransactionBase._begin(self, database, imp_user, bookmarks, access_mode, metadata, timeout)
#      78 self._connection.begin(
#      79     bookmarks=bookmarks, metadata=metadata, timeout=timeout,
#      80     mode=access_mode, db=database, imp_user=imp_user
#      81 )
#      82 self._error_handling_connection.send_all()
# ---> 83 self._error_handling_connection.fetch_all()
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_common.py:180, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     178 def inner(*args, **kwargs):
#     179     try:
# --> 180         func(*args, **kwargs)
#     181     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_bolt.py:672, in Bolt.fetch_all(self)
#     670 response = self.responses[0]
#     671 while not response.complete:
# --> 672     detail_delta, summary_delta = self.fetch_message()
#     673     detail_count += detail_delta
#     674     summary_count += summary_delta
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_bolt.py:655, in Bolt.fetch_message(self)
#     652     return 0, 0
#     654 # Receive exactly one message
# --> 655 tag, fields = self.inbox.pop(
#     656     hydration_hooks=self.responses[0].hydration_hooks
#     657 )
#     658 res = self._process_message(tag, fields)
#     659 self.idle_since = perf_counter()
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_common.py:74, in Inbox.pop(self, hydration_hooks)
#      73 def pop(self, hydration_hooks):
# ---> 74     self._buffer_one_chunk()
#      75     try:
#      76         size, tag = self._unpacker.unpack_structure_header()
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_common.py:53, in Inbox._buffer_one_chunk(self)
#      50 while True:
#      51     while chunk_size == 0:
#      52         # Determine the chunk size and skip noop
# ---> 53         receive_into_buffer(self._socket, self._buffer, 2)
#      54         chunk_size = self._buffer.pop_u16()
#      55         if chunk_size == 0:
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_sync\io\_common.py:293, in receive_into_buffer(sock, buffer, n_bytes)
#     291 with memoryview(buffer.data) as view:
#     292     while buffer.used < end:
# --> 293         n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#     294         if n == 0:
#     295             raise OSError("No data")
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:472, in BoltSocket.recv_into(self, buffer, nbytes)
#     471 def recv_into(self, buffer, nbytes):
# --> 472     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
# File ~\anaconda3\envs\DMML\lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:447, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     445 def _wait_for_io(self, func, *args, **kwargs):
#     446     if self._deadline is None:
# --> 447         return func(*args, **kwargs)
#     448     timeout = self._socket.gettimeout()
#     449     deadline_timeout = self._deadline.to_timeout()
#
# KeyboardInterrupt:

# %%
mu, sigma = 600,120 # mean and standard deviation
followers = np.random.normal(mu, sigma, len(organizer))
followers = np.sort(followers)

# %%
connection = Neo4jDAO("bolt://localhost:7687", "neo4j", "root")
organizer = users[1:228]
for user in organizer:
    for i in range(0,int(followers[j])):
        print(users[(1+i)]['username']," - FOLLOWS -> ", user['username'])
        connection.create_follo(user['username'], users[(1+i)]['username'])
connection.close()
# Out:
# Vincenzo0  - FOLLOWS ->  Vincenzo0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 3>()
#       4     for i in range(0,int(followers[j])):
#       5         print(users[(1+i)]['username']," - FOLLOWS -> ", user['username'])
# ----> 6         connection.create_follow(user['username'], users[(1+i)]['username'])
#       7 connection.close()
#
# AttributeError: 'Neo4jDAO' object has no attribute 'create_follow'
